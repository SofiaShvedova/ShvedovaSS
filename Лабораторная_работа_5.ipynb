# %% [markdown]
# <a href="https://colab.research.google.com/github/SofiaShvedova/ShvedovaSS/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# *   Новый пункт
# *   Новый пункт

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_05_02_01.
#
# Выполнил: Шведова Софья Сергеевна
# Группа: АДЭУ-211
# E-mail: shvedova_sofiya23@mail.ru



class sgn: # создание класса sgn
  def __init__(self,x,y,result = 0, result1 = 0): # конструктор
    self.x = x
    self.y = y
    self.result = result
    self.result1 = result1

  def sgn1(self): # функция-метод 1: сигнум функции х
    if self.x > 0:
      self.result = 1
      return self.result
    elif self.x < 0:
      self.result = -1
      return self.result
    else:
      self.result = 0
      return self.result
  def sgn2(self): # функция-метод 2: сигнум функции y
    if self.y > 0:
      self.result1 = 1
      return self.result1
    elif self.y < 0:
      self.result1 = -1
      return self.result1
    else:
      self.result1 = 0
      return self.result1

  def sgn3(self): # функция-метод 3: вычисление значения z
    z = round((self.result+y**2)/(self.result1-(abs(x**0.5))),2)
    return z
a = sgn(int(input("Введите x: ")),int(input("Введите y: "))) # Создание 1-ого объекта класса sgn
a.sgn1()
a.sgn2()
print("Ответ:",a.sgn3())
# Out:
# Введите x: -9
# Введите y: 0
# Ответ: 0.33

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_05_02_02.
#
# Выполнил: Шведова Софья Сергеевна
# Группа: АДЭУ-211
# E-mail: shvedova_sofiya23@mail.ru


m = 0
summ = 0
class Data: # Создание класса Data
  def __init__(self,izm): # конструктор
    self.izm = izm

  def ysl(self): # функция-метод 1: ввод измерений и запись в сумму всех измерений
    global summ # глобальная область видимости переменной summ
    for i in range(self.izm): # создание цикла
      m = input("Измерение {} - ".format(i+1))
      if m == "":
        self.izm = self.izm - 1
      else:
        summ += int(m)
  def avg(self):  # функция-метод 2: средняя температура
    return summ/self.izm


a = Data(int(input("Введите количество измерений:")))  # создание 1-ого объекта класса Data
print("Количество измерений:", a.izm)
a.ysl()
print("Средняя температура", a.avg())
# Out:
# Количество измерений: 3
# Измерение 1 - 1
# Измерение 2 - 2
# Измерение 3 - 3
# Средняя температура 2.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_05_02_07.
#
# Выполнил: Шведова Софья Сергеевна
# Группа: АДЭУ-211
# E-mail: shvedova_sofiya23@mail.ru

m = 0
sentences = 0
class sentence: # Создание класса sentence
  def __init__(self,n): # конструктор
    self.n = n


  def has_digits(self): # функция-метод 1: поиск цифр в предложениях и + ввод самих предложений
    global sentences # глобальная область видимости переменной sentences
    for i in range(self.n): # цикл
      m = str(input("Предложение № {} - ".format(i+1))) # ввод предложений
      if m.find("1") != -1:
        sentences += 1
      elif m.find("2") != -1:
        sentences += 1
      elif m.find("3") != -1:
        sentences += 1  
      elif m.find("4") != -1:
        sentences += 1   
      elif m.find("5") != -1:
        sentences += 1
      elif m.find("6") != -1:
        sentences += 1
      elif m.find("7") != -1:
        sentences += 1
      elif m.find("8") != -1:
        sentences += 1
      elif m.find("9") != -1:
        sentences += 1
      elif m.find("0") != -1:
        sentences += 1
      else:
        self.n = self.n-1

  def sentences_with_digits_count(self): # функция-метод 2: количество преложений с цифрами
    return sentences

a = sentence(int(input("Введите количество предложений: "))) # создание 1-ого объекта класса sentence
a.has_digits()
print("Количество предложений с цифрами:",a.sentences_with_digits_count())
# Out:
# Введите количество предложений: 3
# Предложение № 1 - Привет
# Предложение № 2 - Мне 18 лет
# Предложение № 3 - А тебе
# Количество предложений с цифрами: 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_05_02_08.
#
# Выполнил: Шведова Софья Сергеевна
# Группа: АДЭУ-211
# E-mail: shvedova_sofiya23@mail.ru



def print_with_border(string,t): # функция-метод: создание рамочки
  w = len(string) + 2 # подсчет количество символов, чтобы создать рамочку нужной ширины
  print(t * w + '\n' + t + string.center(w-2) + t + '\n' + t * w) # создание рамки, .center() - выравнивание по центру

print_with_border(input("Введите текст: "),input("Введите символ: ")) # ввод строки и символа и вывод самой рамочки
# Out:
# Введите текст: Введите введенный текст
# Введите символ: +
# +++++++++++++++++++++++++
# +Введите введенный текст+
# +++++++++++++++++++++++++

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_05_02_09.
#
# Выполнил: Шведова Софья Сергеевна
# Группа: АДЭУ-211
# E-mail: shvedova_sofiya23@mail.ru


a2 = '01' # для перевода из десятичной в указанную
a3 = '012'
a4 = '0123'
a5 = '01234'
a6 = '012345'
a7 = '0123456'
a8 = '01234567'
a9 = '012345678'
a10 = '0123456789'
a11 = '0123456789A'
a12 = '0123456789AB'
a13 = '0123456789ABC'
a14 = '0123456789ABCD'
a15 = '0123456789ABCDE'
a16 ='0123456789ABCDEF'
s = ''
def to_base(number,base): # функция-метод 1: перевод из десятичной в указанную
  global s # глобальная переменная
  if base == 16: # условия
    while number > 0:
      s = a16[number % 16] + s
      number = number // 16
    return s
  elif base == 2:
    while number > 0:
      s = a2[number % 2] + s
      number = number // 2
    return s
  elif base == 3:
    while number > 0:
      s = a3[number % 3] + s
      number = number // 3
    return s
  elif base == 4:
    while number > 0:
      s = a4[number % 4] + s
      number = number// 4
    return s
  elif base == 5:
    while number > 0:
      s = a5[number % 5] + s
      number = number // 5
    return s
  elif number == 6:
    while number > 0:
      s = a6[number % 6] + s
      number = number // 6
    return s
  elif base == 7:
    while number > 0:
      s = a7[number % 7] + s
      number = number // 7
    return s
  elif base == 8:
    while number > 0:
      s = a8[number % 8] + s
      number = number // 8
    return s
  elif base == 9:
    while number > 0:
      s = a9[number % 9] + s
      number = number // 29
    return s
  elif base == 11:
    while number > 0:
      s = a11[number % 11] + s
      number = number // 11
    return s
  elif base == 12:
    while number > 0:
      s = a12[number % 12] + s
      number = number // 12
    return s
  elif base == 13:
    while number > 0:
      s = a13[number % 13] + s
      number = number // 13
    return s
  elif base == 14:
    while number > 0:
      s = a14[number % 14] + s
      number = number // 14
    return s
  elif number == 15:
    while number > 0:
      number = a15[number % 15] + s
      number = number // 15
    return s
  else:
    return "Перевод возможен только в те системы счисления, лежащие в промежутке от 2 до 16"

def from_base(number1, base1): # функция-метод 2: перевод из указанной системы счисления в десятичную
    r = 0
    d = 0
    while number1 > 0:
        d = d + number1 % 10 * base1 ** r
        r += 1
        number1 //= 10
    return d

number = int(input("Введите число для перевода(десятичная с.с.): ")) # ввод
base = int(input("Введите систему счисления: ")) # ввод
print("Перевод из десятичной в указанную:",to_base(number,base)) # вывод
print()
number1 = int(input("Введите число для перевода: ")) # ввод
base1 = int(input("Введите систему счисления для перевода в десятичную: ")) # ввод
print("Перевод из указанной системы счисления в десятичную:",from_base(number1,base1)) # вывод
# Out:
# Введите число для перевода(десятичная с.с.): 64638
# Введите систему счисления: 14
# Перевод из десятичной в указанную: 197B0
#
# Введите число для перевода: 4364
# Введите систему счисления для перевода в десятичную: 7
# Перевод из указанной системы счисления в десятичную: 1565

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_05_02_10.
#
# Выполнил: Шведова Софья Сергеевна
# Группа: АДЭУ-211
# E-mail: shvedova_sofiya23@mail.ru


def sentence_stats(sentence): # функция-метод: статистика символ=количество
  m={} # создание списка
  for i in set(sentence): # цикл для вывода в статистике
      m[i]=s.count(i) # подсчёт количества одинаковых букв
  print(m) # вывод

sentence_stats(input("Введите текст: ")) # ввод текста и тем самым происходит вывод статистики символ=количество
# Out:
# Введите текст: как дела
# {' ': 1, 'л': 1, 'д': 1, 'к': 2, 'е': 1, 'а': 2}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_05_02_11.
#
# Выполнил: Шведова Софья Сергеевна
# Группа: АДЭУ-211
# E-mail: shvedova_sofiya23@mail.ru



def ceasar(text, shift): # функция-метод: шифрование введенной строки
    if text.isalpha(): # isalpha() - если ввведеный текст полностью является альфавитным
        number = ord(letter) + shift % 32 # ord() принимает один символ или строку длиной в один символ и возвращает соответствующее значение, а также происходит прибавление остатка от деления сдвига
        if number  > 1103: # перевод в шифр Цезаря
            number -= 32
        return chr(number) # противоположность ord(), т.е. возвращает строку, представляющую символ для переданного числа
    return text


shift = int(input("Сдвиг: ")) # ввод сдвига
for i in input("Введите строку: "): # ввод строки в цикле
  print(ceasar_encode(i, shift), end='') # вывод шифра Цезаря, end='' - в одну строку
# Out:
# Сдвиг: 4
# Введите строку: Программирование С++
# Уфтзфдррмфтждсмй Х++

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_05_02_14.
#
# Выполнил: Шведова Софья Сергеевна
# Группа: АДЭУ-211
# E-mail: shvedova_sofiya23@mail.ru



def tpl_sort(tpl): # функция-метод 1: расположение отрицательных объектов по убыванию
    for element in tpl: # создание цикла
        if not isinstance(element, int): # если объект не является элементом класса
            return tpl
    tpl = [element for element in tpl if element < 0] # требования для включения элемента в список
    return tuple(sorted(tpl,reverse=True)) # сортировка по убыванию, tuple - кортеж, то есть создание неизменяемого списка

def tpl_sort1(tpl): # функция-метод 1: расположение неотрицательных объектов по возрастанию
    for element in tpl: # создание цикла
        if not isinstance(element, int): # если объект не является элементом класса
            return tpl
    tpl = [element for element in tpl if element >= 0] # требования для включения элемента в список
    return tuple(sorted(tpl)) # сортировка по возрастанию, tuple - кортеж, то есть создание неизменяемого списка
print(tpl_sort((-4,5, 5, -2,3, 1, 9,3,-1)),tpl_sort1((-4,5, 5, -2,3, 1, 9,3,-1))) # вывод
# Out:
# (-1, -2, -4) (1, 3, 3, 5, 5, 9)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_05_02_16.
# 
# Выполнил: Шведова Софья Сергеевна
# Группа: АДЭУ-211
# E-mail: shvedova_sofiya23@mail.ru



def pow1(value,power): # функция-метод 1: без рeкурсии
  return value**power

def pow2(value,power): # функция-метод 2: c рeкурсией
  return 1 if power == 0 else value * BinPow(value, power - 1)
      

print(pow1(5, 3))
print(pow2(5, 3))
# Out:
# 125
# 125

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_05_02_17.
# 
# Выполнил: Шведова Софья Сергеевна
# Группа: АДЭУ-211
# E-mail: shvedova_sofiya23@mail.ru


def digits_sum(value,result = 0): # функция-метод 1: вычисление суммы цифр числа
    if not value:
      return result
    result += value%10 # остаток от деления
    value //= 10 # получение целой части от деления
    return digits_sum(value, result)
              

def digits_count(value, result1 = 0): # функция-метод 1: вычисление количества цифр числа
    if not value:
      return result1
    while(value > 0): # пока число больше 0 выполнять цикл
      result1 = result1 + 1
      value = value // 10 # получение целой части от деления
    return digits_sum(value, result1)


print("Сумма цифр числа =",digits_sum(12345)) # вывод
print("Количество цифр числа =",digits_count(12345)) # вывод
# Out:
# Сумма цифр числа = 15
# Количество цифр числа = 5
